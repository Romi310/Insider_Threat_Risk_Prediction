# %% [markdown]
# ## Capstone: Insider Threat Detection
#
# ### Data Preparation
#
# #### Extract data for Departments "Engineering" and "Software Management" of Functional Unit-2 (Research and Engineering)

# %%
import pandas as pd

# %%
FU2_users = pd.read_csv('./Data_subset/FU2.csv')

# %%
FU2_users.shape
# Out:
# (232, 3)

# %%
FU2_users.head()
# Out:
#    user_id             functional_unit       department
# 0  HBB0090  2 - ResearchAndEngineering  3 - Engineering
# 1  QCF0390  2 - ResearchAndEngineering  3 - Engineering
# 2  JDD0087  2 - ResearchAndEngineering  3 - Engineering
# 3  AAN0077  2 - ResearchAndEngineering  3 - Engineering
# 4  GJP0098  2 - ResearchAndEngineering  3 - Engineering

# %%
device = pd.read_csv('./CERT_Data/r3.2/device.csv')

# %%
device.shape
# Out:
# (407908, 5)

# %%
device.head()
# Out:
#                          id                 date     user       pc    activity
# 0  {R8N4-R8YE70QN-3287FCGL}  01/01/2010 06:46:40  RPM0600  PC-9164     Connect
# 1  {S2M7-P6FL85EG-7721KZFG}  01/01/2010 07:33:10  RPM0600  PC-9164  Disconnect
# 2  {T6E3-Z4ZI24WS-2427MCYM}  01/01/2010 07:59:59  RPM0600  PC-9164     Connect
# 3  {U7O7-D2ZJ25RP-9120NPLP}  01/01/2010 08:02:14  WXW0044  PC-9422     Connect
# 4  {F4W5-B9ID71RL-3407HBRZ}  01/01/2010 08:05:12  CSD0242  PC-8696     Connect

# %%
logon = pd.read_csv('./CERT_Data/r3.2/logon.csv')

# %%
logon.shape
# Out:
# (845351, 5)

# %%
logon.head()
# Out:
#                          id                 date     user       pc activity
# 0  {Q9R3-U1PE27LQ-2164BJLT}  01/01/2010 06:20:00  SLW0616  PC-0110    Logon
# 1  {R1B6-S0LQ34EP-3361QPTV}  01/01/2010 06:28:00  RPM0600  PC-9164    Logon
# 2  {Y3R9-H0JY37RA-5902HXNX}  01/01/2010 07:04:00  DAM0170  PC-1525    Logon
# 3  {D5B1-I6BP26NF-3845HZNZ}  01/01/2010 07:23:00  WXW0044  PC-9422    Logon
# 4  {I0N6-I9PB69SZ-5272SLAT}  01/01/2010 07:31:00  RLD0349  PC-1290    Logon

# %%
len(logon['pc'].unique())
# Out:
# 947

# %%
files = pd.read_csv('./CERT_Data/r3.2/file.csv')

# %%
files.shape
# Out:
# (434769, 6)

# %%
files.head()
# Out:
#                          id                 date     user       pc  \
# 0  {M8R9-I5RI11PG-5467DBVR}  01/01/2010 06:51:00  RPM0600  PC-9164
# 1  {K7D4-F3MJ16HT-2340NUGJ}  01/01/2010 08:09:28  CSD0242  PC-8696
# 2  {B1G0-C3CC52KM-8002OOIA}  01/01/2010 08:17:52  CSD0242  PC-8696
# 3  {D7F8-W4CG21DB-5694PJWH}  01/01/2010 08:18:33  WXW0044  PC-9422
# 4  {B7Y6-R0HX46WQ-8863CNGR}  01/01/2010 08:20:17  CSD0242  PC-8696
#
#        filename                                            content
# 0  5B9VCBIU.doc  D0-CF-11-E0-A1-B1-1A-E1 m45 adss arxiv 1128955...
# 1  1I1WA4EL.txt  58-38-59-4B barbiger detmoldii labillardire 97...
# 2  GSQEMB1R.doc  D0-CF-11-E0-A1-B1-1A-E1 rearers broody fattene...
# 3  RDAOYBUK.txt  4B-4E-43-54 alboin salona turisindus audoin el...
# 4  D92Z9FA8.pdf  25-50-44-46-2D wreckhouse till31122007 59 nia ...

# %%
psychometric = pd.read_csv('./CERT_Data/r3.2/psychometric.csv')

# %%
psychometric.shape
# Out:
# (1000, 7)

# %%
psychometric.head()
# Out:
#             employee_name  user_id   O   C   E   A   N
# 0      Sara Indigo Berger  SIB0825  45  39  41  25  33
# 1       Nerea Ingrid Good  NIG0433  41  30  21  20  32
# 2     Maggy Maryam Newman  MMN0579  35  36  42  16  31
# 3      Asher Lucas Daniel  ALD0521  30  31  19  36  28
# 4  Jael Phyllis Contreras  JPC0464  12  39  21  19  36

# %% [markdown]
# ### Data Extraction

# %%
# device
fu2_device = device[device.user.isin(FU2_users.user_id)]

# %%
fu2_device.shape
# Out:
# (104988, 5)

# %%
fu2_device.head()
# Out:
#                          id                 date     user       pc    activity
# 3  {U7O7-D2ZJ25RP-9120NPLP}  01/01/2010 08:02:14  WXW0044  PC-9422     Connect
# 4  {F4W5-B9ID71RL-3407HBRZ}  01/01/2010 08:05:12  CSD0242  PC-8696     Connect
# 6  {Y8M7-G8NW93MI-9667NZDY}  01/01/2010 08:31:12  CSD0242  PC-8696  Disconnect
# 7  {C5W0-Q5WH46MM-5160WWDV}  01/01/2010 08:33:35  WXW0044  PC-9422  Disconnect
# 8  {J5L5-Q8JV09SA-1827UVRF}  01/01/2010 08:35:25  LWB0078  PC-7065     Connect

# %%
# logon
fu2_logon = logon[logon.user.isin(FU2_users.user_id)]

# %%
fu2_logon.shape
# Out:
# (186541, 5)

# %%
fu2_logon.head()
# Out:
#                           id                 date     user       pc activity
# 3   {D5B1-I6BP26NF-3845HZNZ}  01/01/2010 07:23:00  WXW0044  PC-9422    Logon
# 5   {V3H7-H5HR83XN-1157PMLU}  01/01/2010 07:32:00  CJG0059  PC-3253    Logon
# 6   {E8E0-L8ZW00GW-3776PYCW}  01/01/2010 07:36:00  DWC0525  PC-2714    Logon
# 8   {V4R2-K8QN53SE-2469KXXX}  01/01/2010 07:44:02  DWC0525  PC-7496    Logon
# 10  {R0Y0-W8YE53XK-3290BAIP}  01/01/2010 07:45:00  RAW0533  PC-4563    Logon

# %%
# file

fu2_file = files[files.user.isin(FU2_users.user_id)]

# %%
fu2_file.shape
# Out:
# (131000, 6)

# %%
fu2_file.head()
# Out:
#                          id                 date     user       pc  \
# 1  {K7D4-F3MJ16HT-2340NUGJ}  01/01/2010 08:09:28  CSD0242  PC-8696
# 2  {B1G0-C3CC52KM-8002OOIA}  01/01/2010 08:17:52  CSD0242  PC-8696
# 3  {D7F8-W4CG21DB-5694PJWH}  01/01/2010 08:18:33  WXW0044  PC-9422
# 4  {B7Y6-R0HX46WQ-8863CNGR}  01/01/2010 08:20:17  CSD0242  PC-8696
# 5  {V0Z3-U9EQ92ZX-9558RSZU}  01/01/2010 08:20:26  WXW0044  PC-9422
#
#        filename                                            content
# 1  1I1WA4EL.txt  58-38-59-4B barbiger detmoldii labillardire 97...
# 2  GSQEMB1R.doc  D0-CF-11-E0-A1-B1-1A-E1 rearers broody fattene...
# 3  RDAOYBUK.txt  4B-4E-43-54 alboin salona turisindus audoin el...
# 4  D92Z9FA8.pdf  25-50-44-46-2D wreckhouse till31122007 59 nia ...
# 5  U2M1SJ6Q.doc  D0-CF-11-E0-A1-B1-1A-E1 terrified imbibed proc...

# %%
# psychometric

fu2_psychometric = psychometric[psychometric.user_id.isin(FU2_users.user_id)]

# %%
fu2_psychometric.shape
# Out:
# (232, 7)

# %% [markdown]
# ### Check for missing values in each dataset

# %%
fu2_device.isnull().sum()
# Out:
# id          0
# date        0
# user        0
# pc          0
# activity    0
# dtype: int64

# %%
fu2_logon.isnull().sum()
# Out:
# id          0
# date        0
# user        0
# pc          0
# activity    0
# dtype: int64

# %%
fu2_file.isnull().sum()
# Out:
# id          0
# date        0
# user        0
# pc          0
# filename    0
# content     0
# dtype: int64

# %%
fu2_psychometric.isnull().sum()
# Out:
# employee_name    0
# user_id          0
# O                0
# C                0
# E                0
# A                0
# N                0
# dtype: int64

# %% [markdown]
# ### Save the datasets

# %%
fu2_device.to_csv('./Data_Subset/fu2_device.csv', index = False)

# %%
fu2_logon.to_csv('./Data_Subset/fu2_logon.csv', index = False)

# %%
fu2_file.to_csv('./Data_Subset/fu2_file.csv', index = False)

# %%
fu2_psychometric.to_csv('./Data_Subset/fu2_psychometric.csv', index = False)

# %% [markdown]
# ### Data Preparation for Graph parameters

# %%
logon1 = fu2_logon.groupby(['user', 'pc', 'activity']).size().reset_index() # reset_index() to return result as a df.

# %%
logon1
# Out:
#          user       pc activity    0
# 0     AAN0077  PC-9130   Logoff  340
# 1     AAN0077  PC-9130    Logon  340
# 2     AAW0103  PC-5914   Logoff  345
# 3     AAW0103  PC-5914    Logon  345
# 4     ACE0265  PC-2723   Logoff  345
# 5     ACE0265  PC-2723    Logon  345
# 6     ACL0394  PC-6394   Logoff  345
# 7     ACL0394  PC-6394    Logon  345
# 8     ACL0394  PC-7496   Logoff   27
# 9     ACL0394  PC-7496    Logon   27
# 10    ADR0362  PC-7874   Logoff  345
# 11    ADR0362  PC-7874    Logon  345
# 12    AEA0062  PC-8119   Logoff  345
# 13    AEA0062  PC-8119    Logon  345
# 14    AGD0524  PC-4062   Logoff  345
# 15    AGD0524  PC-4062    Logon  345
# 16    AGP0775  PC-5852   Logoff  345
# 17    AGP0775  PC-5852    Logon  344
# 18    AHS0228  PC-5451   Logoff  345
# 19    AHS0228  PC-5451    Logon  345
# 20    AJB0408  PC-1724   Logoff  345
# 21    AJB0408  PC-1724    Logon  345
# 22    AJH0366  PC-7496   Logoff   81
# 23    AJH0366  PC-7496    Logon   81
# 24    AJH0366  PC-9023   Logoff  345
# 25    AJH0366  PC-9023    Logon  626
# 26    AJQ0376  PC-8111   Logoff  345
# 27    AJQ0376  PC-8111    Logon  345
# 28    AJR0231  PC-0195   Logoff    1
# 29    AJR0231  PC-0195    Logon    1
# ...       ...      ...      ...  ...
# 1250  WMP0272  PC-8764   Logoff    1
# 1251  WMP0272  PC-8764    Logon    1
# 1252  WMP0272  PC-9380   Logoff    1
# 1253  WMP0272  PC-9380    Logon    1
# 1254  WMP0272  PC-9799   Logoff    1
# 1255  WMP0272  PC-9799    Logon    1
# 1256  WMP0272  PC-9980   Logoff    1
# 1257  WMP0272  PC-9980    Logon    1
# 1258  WXW0044  PC-7496   Logoff   21
# 1259  WXW0044  PC-7496    Logon   21
# 1260  WXW0044  PC-9422   Logoff  453
# 1261  WXW0044  PC-9422    Logon  814
# 1262  XBH0901  PC-8356   Logoff  345
# 1263  XBH0901  PC-8356    Logon  345
# 1264  XCR0407  PC-4962   Logoff   67
# 1265  XCR0407  PC-4962    Logon  118
# 1266  XRE0273  PC-7053   Logoff  345
# 1267  XRE0273  PC-7053    Logon  345
# 1268  XTM0246  PC-7760   Logoff  345
# 1269  XTM0246  PC-7760    Logon  345
# 1270  YJT0368  PC-4330   Logoff  345
# 1271  YJT0368  PC-4330    Logon  345
# 1272  YJT0368  PC-7496   Logoff   15
# 1273  YJT0368  PC-7496    Logon   15
# 1274  YSB0779  PC-6341   Logoff  423
# 1275  YSB0779  PC-6341    Logon  423
# 1276  ZBL0379  PC-4473   Logoff  430
# 1277  ZBL0379  PC-4473    Logon  762
# 1278  ZIF0269  PC-0265   Logoff  345
# 1279  ZIF0269  PC-0265    Logon  345
#
# [1280 rows x 4 columns]

# %%
type(logon1)
# Out:
# pandas.core.frame.DataFrame

# %%
# Rename column '0' as 'activity_cnt'

logon1.rename(columns={0:'activity_cnt'}, inplace=True)

# %%
logon1.head()
# Out:
#       user       pc activity  activity_cnt
# 0  AAN0077  PC-9130   Logoff           340
# 1  AAN0077  PC-9130    Logon           340
# 2  AAW0103  PC-5914   Logoff           345
# 3  AAW0103  PC-5914    Logon           345
# 4  ACE0265  PC-2723   Logoff           345

# %%
# Consider only Logoff (as edge weight for the Graph)
# Subset records for only Logoff from the above dataframe 'logon1'

logoff = logon1.loc[logon1['activity'] == 'Logoff']

# %%
logoff.shape
# Out:
# 640

# %%
logoff.head()
# Out:
#       user       pc activity  activity_cnt
# 0  AAN0077  PC-9130   Logoff           340
# 2  AAW0103  PC-5914   Logoff           345
# 4  ACE0265  PC-2723   Logoff           345
# 6  ACL0394  PC-6394   Logoff           345
# 8  ACL0394  PC-7496   Logoff            27

# %%
# Save the Logoff event data 

logoff.to_csv('./Data_Subset/graph_params_logoff.csv', index = False)

# %%
# edges and weights tuple params for the Graph
weighted_edges = [(row['user'], row['pc'], row['activity_cnt']) for idx, row in logoff.iterrows()]

# %%
weighted_edges
# Out:
# [('AAN0077', 'PC-9130', 340),
#  ('AAW0103', 'PC-5914', 345),
#  ('ACE0265', 'PC-2723', 345),
#  ('ACL0394', 'PC-6394', 345),
#  ('ACL0394', 'PC-7496', 27),
#  ('ADR0362', 'PC-7874', 345),
#  ('AEA0062', 'PC-8119', 345),
#  ('AGD0524', 'PC-4062', 345),
#  ('AGP0775', 'PC-5852', 345),
#  ('AHS0228', 'PC-5451', 345),
#  ('AJB0408', 'PC-1724', 345),
#  ('AJH0366', 'PC-7496', 81),
#  ('AJH0366', 'PC-9023', 345),
#  ('AJQ0376', 'PC-8111', 345),
#  ('AJR0231', 'PC-0195', 1),
#  ('AJR0231', 'PC-0239', 1),
#  ('AJR0231', 'PC-0287', 1),
#  ('AJR0231', 'PC-1112', 1),
#  ('AJR0231', 'PC-1769', 1),
#  ('AJR0231', 'PC-1978', 1),
#  ('AJR0231', 'PC-2028', 1),
#  ('AJR0231', 'PC-2093', 1),
#  ('AJR0231', 'PC-2162', 1),
#  ('AJR0231', 'PC-2513', 1),
#  ('AJR0231', 'PC-2585', 1),
#  ('AJR0231', 'PC-2704', 1),
#  ('AJR0231', 'PC-2900', 1),
#  ('AJR0231', 'PC-3050', 1),
#  ('AJR0231', 'PC-3059', 1),
#  ('AJR0231', 'PC-3364', 1),
#  ('AJR0231', 'PC-3646', 1),
#  ('AJR0231', 'PC-3911', 1),
#  ('AJR0231', 'PC-3922', 1),
#  ('AJR0231', 'PC-4403', 1),
#  ('AJR0231', 'PC-4470', 10),
#  ('AJR0231', 'PC-5012', 1),
#  ('AJR0231', 'PC-5451', 2),
#  ('AJR0231', 'PC-5541', 1),
#  ('AJR0231', 'PC-5559', 1),
#  ('AJR0231', 'PC-6039', 345),
#  ('AJR0231', 'PC-6195', 1),
#  ('AJR0231', 'PC-6207', 1),
#  ('AJR0231', 'PC-6314', 1),
#  ('AJR0231', 'PC-7065', 1),
#  ('AJR0231', 'PC-7496', 91),
#  ('AJR0231', 'PC-7501', 1),
#  ('AJR0231', 'PC-7801', 1),
#  ('AJR0231', 'PC-8140', 1),
#  ('AJR0231', 'PC-8552', 1),
#  ('AJR0231', 'PC-8584', 1),
#  ('AJR0231', 'PC-8696', 1),
#  ('AJR0231', 'PC-8944', 1),
#  ('AJR0231', 'PC-9303', 1),
#  ('AJR0231', 'PC-9994', 1),
#  ('ALC0100', 'PC-0133', 1),
#  ('ALC0100', 'PC-0346', 1),
#  ('ALC0100', 'PC-0704', 2),
#  ('ALC0100', 'PC-1146', 1),
#  ('ALC0100', 'PC-1210', 1),
#  ('ALC0100', 'PC-1498', 1),
#  ('ALC0100', 'PC-1683', 1),
#  ('ALC0100', 'PC-1864', 1),
#  ('ALC0100', 'PC-1976', 1),
#  ('ALC0100', 'PC-2231', 1),
#  ('ALC0100', 'PC-2950', 345),
#  ('ALC0100', 'PC-3136', 1),
#  ('ALC0100', 'PC-3201', 1),
#  ('ALC0100', 'PC-3442', 1),
#  ('ALC0100', 'PC-3725', 1),
#  ('ALC0100', 'PC-5106', 1),
#  ('ALC0100', 'PC-5634', 1),
#  ('ALC0100', 'PC-5639', 1),
#  ('ALC0100', 'PC-5686', 1),
#  ('ALC0100', 'PC-5723', 1),
#  ('ALC0100', 'PC-5823', 1),
#  ('ALC0100', 'PC-6009', 1),
#  ('ALC0100', 'PC-6403', 1),
#  ('ALC0100', 'PC-7268', 1),
#  ('ALC0100', 'PC-7496', 20),
#  ('ALC0100', 'PC-7801', 1),
#  ('ALC0100', 'PC-8443', 1),
#  ('ALC0100', 'PC-8706', 1),
#  ('ALC0100', 'PC-8776', 1),
#  ('ALC0100', 'PC-8835', 1),
#  ('ALC0100', 'PC-8976', 1),
#  ('ALC0100', 'PC-9084', 1),
#  ('ALC0100', 'PC-9205', 1),
#  ('ALC0100', 'PC-9799', 1),
#  ('AMR0656', 'PC-4470', 1),
#  ('AMR0656', 'PC-5541', 345),
#  ('AMR0656', 'PC-7496', 116),
#  ('AMW0097', 'PC-4851', 345),
#  ('AOD0066', 'PC-7496', 8),
#  ('AOD0066', 'PC-9400', 123),
#  ('AOP0898', 'PC-6303', 345),
#  ('APH0382', 'PC-0953', 156),
#  ('ARH0777', 'PC-1901', 1),
#  ('ARH0777', 'PC-2594', 1),
#  ('ARH0777', 'PC-3172', 1),
#  ('ARH0777', 'PC-5513', 359),
#  ('ARH0777', 'PC-7496', 77),
#  ('ASH0413', 'PC-2900', 345),
#  ('AWW0784', 'PC-6748', 345),
#  ('BBB0904', 'PC-1695', 345),
#  ('BCP0247', 'PC-9387', 414),
#  ('BDS0396', 'PC-4470', 1),
#  ('BDS0396', 'PC-4931', 345),
#  ('BDS0396', 'PC-7496', 21),
#  ('BER0398', 'PC-7123', 345),
#  ('BFM0101', 'PC-4899', 345),
#  ('BGZ0902', 'PC-1294', 1),
#  ('BGZ0902', 'PC-1551', 1),
#  ('BGZ0902', 'PC-1936', 1),
#  ('BGZ0902', 'PC-2423', 1),
#  ('BGZ0902', 'PC-2599', 1),
#  ('BGZ0902', 'PC-2903', 1),
#  ('BGZ0902', 'PC-4099', 345),
#  ('BGZ0902', 'PC-4396', 1),
#  ('BGZ0902', 'PC-4626', 1),
#  ('BGZ0902', 'PC-5752', 1),
#  ('BGZ0902', 'PC-6403', 1),
#  ('BGZ0902', 'PC-6411', 1),
#  ('BGZ0902', 'PC-7856', 1),
#  ('BGZ0902', 'PC-7974', 1),
#  ('BGZ0902', 'PC-8361', 1),
#  ('BGZ0902', 'PC-9119', 1),
#  ('BGZ0902', 'PC-9303', 1),
#  ('BGZ0902', 'PC-9475', 1),
#  ('BGZ0902', 'PC-9514', 1),
#  ('BGZ0902', 'PC-9755', 1),
#  ('BIT0900', 'PC-0652', 345),
#  ('BKA0340', 'PC-6389', 345),
#  ('BKA0340', 'PC-7496', 20),
#  ('BKA0532', 'PC-5976', 345),
#  ('BMS0057', 'PC-4131', 351),
#  ('BMT0903', 'PC-8416', 345),
#  ('BNS0910', 'PC-3330', 345),
#  ('BOK0261', 'PC-0017', 345),
#  ('BPH0243', 'PC-6434', 345),
#  ('BQK0526', 'PC-5886', 345),
#  ('BRM0377', 'PC-7750', 345),
#  ('BSH0402', 'PC-3275', 345),
#  ('BSR0244', 'PC-5556', 345),
#  ('BXJ0256', 'PC-9303', 345),
#  ('BYN0338', 'PC-0203', 345),
#  ('BZK0095', 'PC-5930', 345),
#  ('BZV0067', 'PC-8351', 345),
#  ('CAE0080', 'PC-4470', 1),
#  ('CAE0080', 'PC-6974', 373),
#  ('CAE0080', 'PC-7496', 70),
#  ('CBD0092', 'PC-0966', 345),
#  ('CCG0255', 'PC-3971', 345),
#  ('CEP0238', 'PC-8845', 248),
#  ('CFR0653', 'PC-4600', 226),
#  ('CGH0088', 'PC-3874', 1),
#  ('CGH0088', 'PC-4620', 1),
#  ('CGH0088', 'PC-4626', 345),
#  ('CGH0088', 'PC-7496', 7),
#  ('CGH0088', 'PC-8964', 1),
#  ('CGP0271', 'PC-4923', 345),
#  ('CHG0404', 'PC-9994', 345),
#  ('CJG0059', 'PC-3253', 421),
#  ('CJV0236', 'PC-1284', 345),
#  ('CMS0535', 'PC-2080', 345),
#  ('CPM0659', 'PC-4470', 5),
#  ('CPM0659', 'PC-7496', 30),
#  ('CPM0659', 'PC-7719', 345),
#  ('CQS0899', 'PC-0007', 1),
#  ('CQS0899', 'PC-0026', 1),
#  ('CQS0899', 'PC-0562', 1),
#  ('CQS0899', 'PC-1420', 1),
#  ('CQS0899', 'PC-1683', 1),
#  ('CQS0899', 'PC-2286', 458),
#  ('CQS0899', 'PC-2438', 1),
#  ('CQS0899', 'PC-2513', 1),
#  ('CQS0899', 'PC-2599', 1),
#  ('CQS0899', 'PC-2849', 1),
#  ('CQS0899', 'PC-3476', 1),
#  ('CQS0899', 'PC-4062', 1),
#  ('CQS0899', 'PC-4330', 1),
#  ('CQS0899', 'PC-4414', 1),
#  ('CQS0899', 'PC-4769', 1),
#  ('CQS0899', 'PC-5406', 1),
#  ('CQS0899', 'PC-5490', 1),
#  ('CQS0899', 'PC-6010', 1),
#  ('CQS0899', 'PC-6245', 1),
#  ('CQS0899', 'PC-6394', 1),
#  ('CQS0899', 'PC-6504', 1),
#  ('CQS0899', 'PC-7428', 1),
#  ('CQS0899', 'PC-7496', 28),
#  ('CQS0899', 'PC-8570', 1),
#  ('CQS0899', 'PC-8835', 1),
#  ('CQS0899', 'PC-9137', 1),
#  ('CQS0899', 'PC-9299', 1),
#  ('CRL0906', 'PC-1859', 345),
#  ('CSD0242', 'PC-8696', 404),
#  ('CSW0531', 'PC-4470', 1),
#  ('CSW0531', 'PC-5732', 230),
#  ('CSW0531', 'PC-7496', 13),
#  ('CUM0234', 'PC-1305', 314),
#  ('DHB0086', 'PC-9191', 345),
#  ('DJG0393', 'PC-4095', 345),
#  ('DJH0245', 'PC-9808', 345),
#  ('DJM0094', 'PC-8372', 345),
#  ('DJS0406', 'PC-9069', 64),
#  ('DNS0397', 'PC-3371', 1),
#  ('DNS0397', 'PC-3396', 1),
#  ('DNS0397', 'PC-4114', 1),
#  ('DNS0397', 'PC-5660', 345),
#  ('DNS0397', 'PC-8372', 1),
#  ('DNS0397', 'PC-8960', 1),
#  ('DRH0268', 'PC-0401', 345),
#  ('DWC0525', 'PC-2714', 382),
#  ('DWC0525', 'PC-7496', 128),
#  ('DYB0399', 'PC-0953', 345),
#  ('DYS0230', 'PC-0560', 345),
#  ('EAD0651', 'PC-6195', 345),
#  ('EBS0102', 'PC-3211', 345),
#  ('EER0383', 'PC-0026', 1),
#  ('EER0383', 'PC-0742', 1),
#  ('EER0383', 'PC-1658', 1),
#  ('EER0383', 'PC-1765', 1),
#  ('EER0383', 'PC-2487', 1),
#  ('EER0383', 'PC-2555', 1),
#  ('EER0383', 'PC-3125', 1),
#  ('EER0383', 'PC-3162', 1),
#  ('EER0383', 'PC-3396', 1),
#  ('EER0383', 'PC-3682', 1),
#  ('EER0383', 'PC-4073', 1),
#  ('EER0383', 'PC-4384', 1),
#  ('EER0383', 'PC-4414', 1),
#  ('EER0383', 'PC-5123', 1),
#  ('EER0383', 'PC-5694', 1),
#  ('EER0383', 'PC-5935', 1),
#  ('EER0383', 'PC-6504', 1),
#  ('EER0383', 'PC-7496', 118),
#  ('EER0383', 'PC-8115', 1),
#  ('EER0383', 'PC-8221', 1),
#  ('EER0383', 'PC-8236', 1),
#  ('EER0383', 'PC-8373', 2),
#  ('EER0383', 'PC-8465', 1),
#  ('EER0383', 'PC-8585', 1),
#  ('EER0383', 'PC-8845', 1),
#  ('EER0383', 'PC-9037', 1),
#  ('EER0383', 'PC-9061', 1),
#  ('EER0383', 'PC-9546', 1),
#  ('EER0383', 'PC-9553', 1),
#  ('EER0383', 'PC-9628', 345),
#  ('EER0383', 'PC-9642', 1),
#  ('EER0383', 'PC-9845', 1),
#  ('EER0383', 'PC-9935', 1),
#  ('EHK0070', 'PC-2988', 345),
#  ('ERC0384', 'PC-8552', 345),
#  ('ETK0783', 'PC-3837', 345),
#  ('FED0275', 'PC-0808', 1),
#  ('FED0275', 'PC-1170', 1),
#  ('FED0275', 'PC-2403', 1),
#  ('FED0275', 'PC-2448', 1),
#  ('FED0275', 'PC-2449', 1),
#  ('FED0275', 'PC-2550', 1),
#  ('FED0275', 'PC-2601', 1),
#  ('FED0275', 'PC-3151', 1),
#  ('FED0275', 'PC-3195', 419),
#  ('FED0275', 'PC-3289', 1),
#  ('FED0275', 'PC-3426', 1),
#  ('FED0275', 'PC-3450', 1),
#  ('FED0275', 'PC-3486', 1),
#  ('FED0275', 'PC-3540', 1),
#  ('FED0275', 'PC-3646', 1),
#  ('FED0275', 'PC-4495', 1),
#  ('FED0275', 'PC-4689', 1),
#  ('FED0275', 'PC-4830', 1),
#  ('FED0275', 'PC-4895', 1),
#  ('FED0275', 'PC-4939', 1),
#  ('FED0275', 'PC-5242', 1),
#  ('FED0275', 'PC-5513', 1),
#  ('FED0275', 'PC-5834', 1),
#  ('FED0275', 'PC-6103', 1),
#  ('FED0275', 'PC-6335', 1),
#  ('FED0275', 'PC-6606', 1),
#  ('FED0275', 'PC-6995', 1),
#  ('FED0275', 'PC-7268', 1),
#  ('FED0275', 'PC-7601', 1),
#  ('FED0275', 'PC-7977', 1),
#  ('FED0275', 'PC-8221', 1),
#  ('FED0275', 'PC-8616', 1),
#  ('FED0275', 'PC-8655', 1),
#  ('FED0275', 'PC-8934', 1),
#  ('FED0275', 'PC-9171', 1),
#  ('FED0275', 'PC-9709', 1),
#  ('FED0275', 'PC-9747', 1),
#  ('FED0275', 'PC-9815', 1),
#  ('FED0275', 'PC-9822', 1),
#  ('FED0275', 'PC-9853', 1),
#  ('FED0275', 'PC-9881', 1),
#  ('FED0275', 'PC-9935', 1),
#  ('FED0275', 'PC-9940', 1),
#  ('FKC0253', 'PC-3170', 345),
#  ('FKF0235', 'PC-1325', 69),
#  ('FML0505', 'PC-9341', 345),
#  ('GAP0262', 'PC-1084', 345),
#  ('GBM0381', 'PC-7496', 20),
#  ('GBM0381', 'PC-8585', 345),
#  ('GFM0250', 'PC-0291', 383),
#  ('GGK0375', 'PC-3364', 345),
#  ('GGM0530', 'PC-7496', 30),
#  ('GGM0530', 'PC-9712', 465),
#  ('GJP0098', 'PC-6435', 345),
#  ('GJP0098', 'PC-7496', 13),
#  ('GOG0650', 'PC-8509', 345),
#  ('GXB0655', 'PC-1133', 310),
#  ('HBB0090', 'PC-3818', 345),
#  ('HBS0270', 'PC-9086', 345),
#  ('HDH0266', 'PC-6606', 345),
#  ('HDH0266', 'PC-7496', 65),
#  ('HGS0657', 'PC-3735', 316),
#  ('HJB0227', 'PC-0700', 345),
#  ('HJB0227', 'PC-7496', 70),
#  ('HKK0363', 'PC-4267', 345),
#  ('HML0060', 'PC-7052', 354),
#  ('HML0060', 'PC-7496', 27),
#  ('HNW0537', 'PC-0031', 345),
#  ('HNW0537', 'PC-4470', 3),
#  ('HNW0537', 'PC-7496', 63),
#  ('HOA0074', 'PC-3411', 345),
#  ('HOJ0260', 'PC-8976', 345),
#  ('HPL0787', 'PC-0799', 405),
#  ('IAF0403', 'PC-6507', 345),
#  ('IAF0403', 'PC-7496', 15),
#  ('INL0534', 'PC-4470', 14),
#  ('INL0534', 'PC-5918', 276),
#  ('INL0534', 'PC-7496', 81),
#  ('IRW0076', 'PC-0337', 345),
#  ('IUM0065', 'PC-3232', 345),
#  ('IZR0263', 'PC-3714', 345),
#  ('JAB0249', 'PC-4178', 345),
#  ('JAF0755', 'PC-0172', 345),
#  ('JCE0258', 'PC-1508', 198),
#  ('JCE0258', 'PC-4470', 1),
#  ('JCE0258', 'PC-7496', 69),
#  ('JDD0087', 'PC-4476', 345),
#  ('JDD0087', 'PC-7496', 115),
#  ('JEC0387', 'PC-2628', 345),
#  ('JJL0257', 'PC-4080', 345),
#  ('JKM0661', 'PC-1739', 345),
#  ('JKR0239', 'PC-5521', 345),
#  ('JLI0073', 'PC-0014', 345),
#  ('JLI0073', 'PC-4470', 19),
#  ('JLI0073', 'PC-7496', 76),
#  ('JMB0781', 'PC-5618', 345),
#  ('JMH0905', 'PC-1960', 345),
#  ('JMT0232', 'PC-3328', 345),
#  ('JNW0252', 'PC-1632', 345),
#  ('JNW0252', 'PC-4470', 3),
#  ('JNW0252', 'PC-7496', 15),
#  ('JOH0068', 'PC-2558', 345),
#  ('JOH0068', 'PC-4470', 4),
#  ('JOH0068', 'PC-7496', 42),
#  ('JPS0880', 'PC-6904', 345),
#  ('JRG0089', 'PC-2039', 345),
#  ('JSN0536', 'PC-2591', 345),
#  ('JSN0536', 'PC-4470', 2),
#  ('JSN0536', 'PC-7496', 115),
#  ('JTB0079', 'PC-5426', 345),
#  ('KAH0660', 'PC-8609', 345),
#  ('KAP0237', 'PC-9935', 533),
#  ('KCR0788', 'PC-9773', 345),
#  ('KCS0267', 'PC-5242', 345),
#  ('KDV0908', 'PC-4055', 345),
#  ('KDV0908', 'PC-7496', 93),
#  ('KFS0225', 'PC-7367', 345),
#  ('KMJ0392', 'PC-6259', 471),
#  ('KRM0241', 'PC-5876', 345),
#  ('KSM0099', 'PC-3853', 73),
#  ('KTP0385', 'PC-9278', 345),
#  ('KWH0391', 'PC-0979', 345),
#  ('KWH0391', 'PC-4470', 1),
#  ('KWH0391', 'PC-7496', 88),
#  ('LAC0649', 'PC-5925', 345),
#  ('LAH0778', 'PC-3563', 121),
#  ('LAH0778', 'PC-4470', 1),
#  ('LAH0778', 'PC-7496', 6),
#  ('LAM0411', 'PC-0346', 345),
#  ('LDC0229', 'PC-6685', 345),
#  ('LEF0786', 'PC-7496', 109),
#  ('LEF0786', 'PC-9334', 345),
#  ('LIP0370', 'PC-1424', 345),
#  ('LJW0776', 'PC-4470', 10),
#  ('LJW0776', 'PC-5436', 429),
#  ('LJW0776', 'PC-7496', 104),
#  ('LMH0373', 'PC-1269', 345),
#  ('LML0259', 'PC-8495', 345),
#  ('LNR0233', 'PC-7284', 345),
#  ('LQD0409', 'PC-4470', 7),
#  ('LQD0409', 'PC-7496', 91),
#  ('LQD0409', 'PC-9494', 345),
#  ('LTB0107', 'PC-6904', 345),
#  ('LTB0107', 'PC-7496', 3),
#  ('LVL0958', 'PC-4470', 8),
#  ('LVL0958', 'PC-5738', 345),
#  ('LVL0958', 'PC-7496', 88),
#  ('LWB0078', 'PC-0207', 1),
#  ('LWB0078', 'PC-0401', 1),
#  ('LWB0078', 'PC-0545', 1),
#  ('LWB0078', 'PC-0757', 1),
#  ('LWB0078', 'PC-1095', 1),
#  ('LWB0078', 'PC-1554', 1),
#  ('LWB0078', 'PC-1798', 1),
#  ('LWB0078', 'PC-2585', 1),
#  ('LWB0078', 'PC-2899', 1),
#  ('LWB0078', 'PC-2937', 1),
#  ('LWB0078', 'PC-3232', 1),
#  ('LWB0078', 'PC-3411', 1),
#  ('LWB0078', 'PC-3452', 1),
#  ('LWB0078', 'PC-3529', 1),
#  ('LWB0078', 'PC-3587', 1),
#  ('LWB0078', 'PC-3725', 1),
#  ('LWB0078', 'PC-3768', 1),
#  ('LWB0078', 'PC-3818', 1),
#  ('LWB0078', 'PC-3922', 1),
#  ('LWB0078', 'PC-4067', 1),
#  ('LWB0078', 'PC-4198', 1),
#  ('LWB0078', 'PC-4220', 1),
#  ('LWB0078', 'PC-4470', 1),
#  ('LWB0078', 'PC-4600', 1),
#  ('LWB0078', 'PC-4620', 1),
#  ('LWB0078', 'PC-5097', 2),
#  ('LWB0078', 'PC-5354', 1),
#  ('LWB0078', 'PC-5852', 1),
#  ('LWB0078', 'PC-6403', 1),
#  ('LWB0078', 'PC-6407', 2),
#  ('LWB0078', 'PC-6411', 1),
#  ('LWB0078', 'PC-6466', 1),
#  ('LWB0078', 'PC-6504', 2),
#  ('LWB0078', 'PC-6820', 1),
#  ('LWB0078', 'PC-6884', 1),
#  ('LWB0078', 'PC-6894', 1),
#  ('LWB0078', 'PC-7065', 489),
#  ('LWB0078', 'PC-7123', 1),
#  ('LWB0078', 'PC-7255', 1),
#  ('LWB0078', 'PC-7345', 1),
#  ('LWB0078', 'PC-7367', 1),
#  ('LWB0078', 'PC-7496', 38),
#  ('LWB0078', 'PC-7719', 1),
#  ('LWB0078', 'PC-7856', 1),
#  ('LWB0078', 'PC-7935', 1),
#  ('LWB0078', 'PC-8495', 1),
#  ('LWB0078', 'PC-8609', 1),
#  ('LWB0078', 'PC-8655', 1),
#  ('LWB0078', 'PC-8706', 1),
#  ('LWB0078', 'PC-9171', 1),
#  ('LWB0078', 'PC-9202', 1),
#  ('LWB0078', 'PC-9589', 1),
#  ('LWB0078', 'PC-9712', 1),
#  ('LWB0078', 'PC-9755', 1),
#  ('LWB0078', 'PC-9994', 1),
#  ('MAB0064', 'PC-0757', 345),
#  ('MAP0091', 'PC-0266', 345),
#  ('MBB0251', 'PC-6121', 345),
#  ('MCB0104', 'PC-6483', 345),
#  ('MCL0405', 'PC-5870', 345),
#  ('MHH0652', 'PC-7174', 345),
#  ('MJH0083', 'PC-2016', 345),
#  ('MJH0083', 'PC-4470', 15),
#  ('MJH0083', 'PC-7496', 106),
#  ('MKH0774', 'PC-5352', 345),
#  ('MLG0658', 'PC-1648', 345),
#  ('MPM0410', 'PC-2423', 345),
#  ('MPM0410', 'PC-4470', 2),
#  ('MPM0410', 'PC-7496', 16),
#  ('MPO0663', 'PC-1102', 345),
#  ('MRH0339', 'PC-5607', 345),
#  ('MSB0359', 'PC-4227', 374),
#  ('MSB0359', 'PC-7496', 21),
#  ('MSC0662', 'PC-3443', 345),
#  ('MTJ0043', 'PC-0147', 345),
#  ('MWL0897', 'PC-2060', 345),
#  ('NGF0226', 'PC-4222', 345),
#  ('NST0254', 'PC-1372', 345),
#  ('NST0254', 'PC-4470', 2),
#  ('NST0254', 'PC-7496', 35),
#  ('NXG0085', 'PC-5097', 345),
#  ('OBC0055', 'PC-4483', 345),
#  ('ORC0907', 'PC-1583', 345),
#  ('ORC0907', 'PC-4470', 4),
#  ('ORC0907', 'PC-7496', 13),
#  ('PNB0084', 'PC-4080', 345),
#  ('PQC0061', 'PC-6530', 345),
#  ('PTH0527', 'PC-6402', 345),
#  ('PYT0264', 'PC-0652', 1),
#  ('PYT0264', 'PC-0726', 1),
#  ('PYT0264', 'PC-1290', 1),
#  ('PYT0264', 'PC-1420', 1),
#  ('PYT0264', 'PC-1729', 1),
#  ('PYT0264', 'PC-1798', 1),
#  ('PYT0264', 'PC-2060', 1),
#  ('PYT0264', 'PC-2162', 1),
#  ('PYT0264', 'PC-2863', 345),
#  ('PYT0264', 'PC-3309', 1),
#  ('PYT0264', 'PC-3328', 1),
#  ('PYT0264', 'PC-4114', 1),
#  ('PYT0264', 'PC-4178', 1),
#  ('PYT0264', 'PC-4179', 1),
#  ('PYT0264', 'PC-4470', 12),
#  ('PYT0264', 'PC-5451', 1),
#  ('PYT0264', 'PC-5660', 1),
#  ('PYT0264', 'PC-6504', 1),
#  ('PYT0264', 'PC-6530', 1),
#  ('PYT0264', 'PC-6552', 1),
#  ('PYT0264', 'PC-6685', 1),
#  ('PYT0264', 'PC-7475', 1),
#  ('PYT0264', 'PC-7496', 52),
#  ('PYT0264', 'PC-7699', 1),
#  ('PYT0264', 'PC-8135', 1),
#  ('PYT0264', 'PC-8373', 1),
#  ('PYT0264', 'PC-8495', 1),
#  ('PYT0264', 'PC-8957', 1),
#  ('PYT0264', 'PC-9799', 1),
#  ('PYT0264', 'PC-9853', 1),
#  ('QCF0390', 'PC-5935', 109),
#  ('QEB0780', 'PC-1864', 345),
#  ('QKA0388', 'PC-1744', 345),
#  ('QLC0248', 'PC-5741', 406),
#  ('QLC0248', 'PC-7496', 29),
#  ('RAC0058', 'PC-6846', 345),
#  ('RAW0533', 'PC-4563', 420),
#  ('RAW0533', 'PC-7496', 23),
#  ('RBH0654', 'PC-3646', 345),
#  ('RCG0105', 'PC-4470', 1),
#  ('RCG0105', 'PC-7496', 26),
#  ('RCG0105', 'PC-8929', 345),
#  ('RCH0106', 'PC-0405', 345),
#  ('RCM0412', 'PC-2702', 345),
#  ('RCM0412', 'PC-4470', 1),
#  ('RCM0412', 'PC-7496', 3),
#  ('REF0374', 'PC-4220', 345),
#  ('REM0274', 'PC-3528', 345),
#  ('RHN0782', 'PC-0217', 345),
#  ('RHW0081', 'PC-6009', 345),
#  ('RIS0909', 'PC-6683', 345),
#  ('RMA0911', 'PC-8970', 345),
#  ('ROS0365', 'PC-9252', 345),
#  ('RRG0041', 'PC-4329', 345),
#  ('SAB0372', 'PC-8960', 345),
#  ('SBM0063', 'PC-2161', 370),
#  ('SBM0063', 'PC-7496', 116),
#  ('SCR0389', 'PC-1916', 351),
#  ('SCR0389', 'PC-7496', 29),
#  ('SDY0367', 'PC-1588', 345),
#  ('SDY0367', 'PC-4470', 6),
#  ('SDY0367', 'PC-7496', 119),
#  ('SHR0369', 'PC-3561', 359),
#  ('SHR0369', 'PC-7496', 36),
#  ('SKC0630', 'PC-8538', 345),
#  ('SKP0371', 'PC-7899', 345),
#  ('SLB0004', 'PC-9037', 345),
#  ('SMM0380', 'PC-2028', 345),
#  ('SNP0785', 'PC-6112', 345),
#  ('SSH0093', 'PC-0500', 345),
#  ('SVM0538', 'PC-2601', 345),
#  ('SVM0538', 'PC-7496', 106),
#  ('TBD0276', 'PC-1649', 345),
#  ('TBF0071', 'PC-1146', 345),
#  ('TCG0400', 'PC-5852', 345),
#  ('TJL0082', 'PC-4470', 10),
#  ('TJL0082', 'PC-7496', 91),
#  ('TJL0082', 'PC-9799', 345),
#  ('TOC0528', 'PC-5949', 345),
#  ('TSE0056', 'PC-9171', 345),
#  ('TTP0529', 'PC-6206', 345),
#  ('TWG0096', 'PC-4660', 345),
#  ('UBM0240', 'PC-2979', 345),
#  ('UMA0072', 'PC-7496', 20),
#  ('UMA0072', 'PC-9245', 345),
#  ('VBB0361', 'PC-5314', 345),
#  ('VCP0364', 'PC-2368', 345),
#  ('VKB0360', 'PC-5752', 345),
#  ('VLB0069', 'PC-0471', 361),
#  ('VRF0401', 'PC-0234', 345),
#  ('WAF0395', 'PC-9994', 345),
#  ('WAS0075', 'PC-5012', 345),
#  ('WCL0378', 'PC-9461', 345),
#  ('WJP0386', 'PC-1305', 1),
#  ('WJP0386', 'PC-1498', 345),
#  ('WJP0386', 'PC-1756', 1),
#  ('WJP0386', 'PC-2285', 1),
#  ('WJP0386', 'PC-4227', 1),
#  ('WJP0386', 'PC-4796', 1),
#  ('WJP0386', 'PC-4851', 1),
#  ('WJP0386', 'PC-5595', 1),
#  ('WJP0386', 'PC-6685', 1),
#  ('WJP0386', 'PC-7700', 1),
#  ('WJP0386', 'PC-9557', 1),
#  ('WJP0386', 'PC-9638', 1),
#  ('WMP0272', 'PC-0167', 1),
#  ('WMP0272', 'PC-0172', 1),
#  ('WMP0272', 'PC-0239', 1),
#  ('WMP0272', 'PC-0266', 1),
#  ('WMP0272', 'PC-0953', 1),
#  ('WMP0272', 'PC-1349', 1),
#  ('WMP0272', 'PC-1366', 1),
#  ('WMP0272', 'PC-1496', 1),
#  ('WMP0272', 'PC-1525', 1),
#  ('WMP0272', 'PC-1609', 1),
#  ('WMP0272', 'PC-1738', 1),
#  ('WMP0272', 'PC-2004', 1),
#  ('WMP0272', 'PC-2016', 1),
#  ('WMP0272', 'PC-2093', 1),
#  ('WMP0272', 'PC-2963', 1),
#  ('WMP0272', 'PC-3162', 1),
#  ('WMP0272', 'PC-4380', 1),
#  ('WMP0272', 'PC-5406', 1),
#  ('WMP0272', 'PC-5426', 1),
#  ('WMP0272', 'PC-5490', 1),
#  ('WMP0272', 'PC-5556', 1),
#  ('WMP0272', 'PC-5949', 1),
#  ('WMP0272', 'PC-5975', 1),
#  ('WMP0272', 'PC-6394', 1),
#  ('WMP0272', 'PC-6403', 345),
#  ('WMP0272', 'PC-6894', 1),
#  ('WMP0272', 'PC-7345', 1),
#  ('WMP0272', 'PC-7496', 36),
#  ('WMP0272', 'PC-8180', 1),
#  ('WMP0272', 'PC-8262', 1),
#  ('WMP0272', 'PC-8615', 1),
#  ('WMP0272', 'PC-8764', 1),
#  ('WMP0272', 'PC-9380', 1),
#  ('WMP0272', 'PC-9799', 1),
#  ('WMP0272', 'PC-9980', 1),
#  ('WXW0044', 'PC-7496', 21),
#  ('WXW0044', 'PC-9422', 453),
#  ('XBH0901', 'PC-8356', 345),
#  ('XCR0407', 'PC-4962', 67),
#  ('XRE0273', 'PC-7053', 345),
#  ('XTM0246', 'PC-7760', 345),
#  ('YJT0368', 'PC-4330', 345),
#  ('YJT0368', 'PC-7496', 15),
#  ('YSB0779', 'PC-6341', 423),
#  ('ZBL0379', 'PC-4473', 430),
#  ('ZIF0269', 'PC-0265', 345)]

# %%
fu2_logon.groupby(['user', 'pc'])['pc'].count()
# Out:
# user     pc
# AAN0077  PC-9130     680
# AAW0103  PC-5914     690
# ACE0265  PC-2723     690
# ACL0394  PC-6394     690
#          PC-7496      54
# ADR0362  PC-7874     690
# AEA0062  PC-8119     690
# AGD0524  PC-4062     690
# AGP0775  PC-5852     689
# AHS0228  PC-5451     690
# AJB0408  PC-1724     690
# AJH0366  PC-7496     162
#          PC-9023     971
# AJQ0376  PC-8111     690
# AJR0231  PC-0195       2
#          PC-0239       2
#          PC-0287       2
#          PC-1112       2
#          PC-1769       2
#          PC-1978       2
#          PC-2028       2
#          PC-2093       2
#          PC-2162       2
#          PC-2513       2
#          PC-2585       2
#          PC-2704       2
#          PC-2900       2
#          PC-3050       2
#          PC-3059       2
#          PC-3364       2
#                     ...
# WMP0272  PC-4380       2
#          PC-5406       2
#          PC-5426       2
#          PC-5490       2
#          PC-5556       2
#          PC-5949       2
#          PC-5975       2
#          PC-6394       2
#          PC-6403     952
#          PC-6894       2
#          PC-7345       2
#          PC-7496      72
#          PC-8180       2
#          PC-8262       2
#          PC-8615       2
#          PC-8764       2
#          PC-9380       2
#          PC-9799       2
#          PC-9980       2
# WXW0044  PC-7496      42
#          PC-9422    1267
# XBH0901  PC-8356     690
# XCR0407  PC-4962     185
# XRE0273  PC-7053     690
# XTM0246  PC-7760     690
# YJT0368  PC-4330     690
#          PC-7496      30
# YSB0779  PC-6341     846
# ZBL0379  PC-4473    1192
# ZIF0269  PC-0265     690
# Name: pc, Length: 640, dtype: int64
